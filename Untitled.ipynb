# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
# 1/                                             Trabajo Grupo/
# 2/                                             Transportistas.mdb
# 3/                                             Untitled.ipynb
# Clientes.csv                                   Vehiculos.csv
# Empleados.csv                                  optimizacion-lineal-r.pdf
# Envios.csv                                     tema-11-investigacion-operativa-con-r (1).pdf
# Optimizacion_Matematica_con_R_Volumen_I.pdf    trabajo individual/
# Paquetes.csv

# %%
pd.read_csv('Empleados.csv', header=0)
# Out:
#    CodEmpleado  Apellidos    Nombre  FechaNacimiento FechaContratación  \
# 0            1    Davolio     Nancy  8/12/70 0:00:00    1/5/04 0:00:00
# 1            2     Fuller    Andrew  19/2/54 0:00:00   14/8/09 0:00:00
# 2            3  Leverling     Janet  30/8/65 0:00:00    1/4/10 0:00:00
# 3            4    Peacock  Margaret  19/9/60 0:00:00    3/5/05 0:00:00
# 4            5   Buchanan    Steven   4/3/57 0:00:00  17/10/08 0:00:00
# 5            6     Suyama   Michael   2/7/65 0:00:00  17/10/05 0:00:00
# 6            7       King    Robert  29/5/62 0:00:00    2/1/11 0:00:00
# 7            8   Callahan     Laura   9/1/60 0:00:00    5/3/06 0:00:00
# 8            9  Dodsworth      Anne   2/7/71 0:00:00  15/11/06 0:00:00
#
#                        Dirección    Ciudad CodPostal    TelDomicilio
# 0     507 - 20th Ave. E. Apt. 2A   Seattle     98122  (206) 555-9857
# 1             908 W. Capital Way    Tacoma     98401  (206) 555-9482
# ...

# %%
empl = _

# %%
pd.read_csv('Envios.csv', header=0)
# Out:
#       CodEnvio             Fecha  CodCliente  CodEmpleado CodVehiculo  \
# 0            1   1/11/14 0:00:00          79            7    3851-CBT
# 1            2   1/11/14 0:00:00          80            8    8745-CBF
# 2            3   1/11/14 0:00:00          63            9   Z-2345-BJ
# 3            4   1/11/14 0:00:00          48            9   Z-2345-BJ
# 4            5   1/11/14 0:00:00          82            1   Z-2675-BF
# 5            6   1/11/14 0:00:00          34            1   Z-2675-BF
# 6            7   1/11/14 0:00:00          91            1   Z-2675-BF
# 7            8   1/11/14 0:00:00          39            1   Z-2675-BF
# 8            9   1/11/14 0:00:00          74            1   Z-2675-BF
# 9           10   2/11/14 0:00:00          19            9    3851-CBT
# 10          11   2/11/14 0:00:00           9            1    8745-CBF
# 11          12   2/11/14 0:00:00          86            1    8745-CBF
# ...

# %%
envios = _

# %%
pd.read_csv('Paquetes.csv', header=0)
# Out:
#        CodPaquete  CodEnvio  Tipo    Peso
# 0               2         1   NaN  350.28
# 1               3         1   NaN  411.29
# 2               4         1   NaN  329.28
# 3               5         2   NaN  299.90
# 4               6         2   NaN  310.14
# 5               7         2   NaN  304.99
# 6               8         2   NaN  344.49
# 7               9         2   NaN  260.44
# 8              10         3   NaN  201.57
# 9              11         3   NaN  200.50
# 10             12         4   NaN  187.95
# 11             13         4   NaN  213.59
# 12             14         4   NaN  165.84
# 13             15         5   NaN    0.22
# 14             16         6   NaN    0.28
# 15             17         6   NaN    0.92
# 16             18         6   NaN    0.95
# 17             19         7   NaN    0.83
# 18             20         7   NaN    1.09
# 19             21         7   NaN    0.35
# 20             22         7   NaN    0.19
# ...

# %%
paquetes = _

# %%
pd.read_csv('Vehiculos.csv', header=0)
# Out:
#    Matricula        Descripcion  Capacidad
# 0   3851-CBT      Camion grande       1500
# 1   8745-CBF  Camioneta reparto       1200
# 2  Z-2345-BJ  Furgoneta Transit        800
# 3  Z-2675-BF              Vespa         10
# 4  Z-2676-BF              Vespa         10
# 5  Z-4678-BF    Renault Express        400
# 6  Z-8113-BK   Coche industrial        500
# 7  Z-8114-BK      Coche reparto        400

# %%
vehiculos = _

# %%
len(paquetes[paquetes.Peso > 200])
# Out:
# 4111
